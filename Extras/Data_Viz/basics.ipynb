# %% [markdown]
# # Seaborn Data Visualization

# %% [markdown]
# # Table of Contents
# 1. [Seaborn Data Visualization](#seaborn-data-visualization)
#     1. [Lineplot](#lineplot)
#     2. [Bar Charts and Heatmaps](#bar-charts-and-heatmaps)
#         1. [Heatmaps](#heatmaps)
#     3. [Scatter Plots](#scatter-plots)
#     4. [Distributions](#distributions)
#         1. [Histogram](#histogram)
#         2. [Density Plots](#density-plots)

# %%
"""
This script sets up the environment for data visualization using pandas, matplotlib, and seaborn.

Imports:
- pandas as pd: Imports the pandas library and aliases it as 'pd'.
- pd.plotting.register_matplotlib_converters(): Registers pandas formatters and converters with matplotlib.
- matplotlib.pyplot as plt: Imports the pyplot module from matplotlib and aliases it as 'plt'.
- %matplotlib inline: A magic function to display matplotlib plots inline within Jupyter notebooks.
- seaborn as sns: Imports the seaborn library and aliases it as 'sns'.

Usage:
- Ensure that the necessary libraries (pandas, matplotlib, seaborn) are installed.
- Run this script in a Jupyter notebook to set up the environment for data visualization.

Example:
# After running this setup script, you can create a simple plot as follows:

# Sample data
data = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [10, 20, 25, 30, 35]
})

# Create a line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='x', y='y')
plt.title('Sample Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
"""
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

pd.plotting.register_matplotlib_converters()

# %matplotlib inline

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning)


print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # Lineplot

# %%
file_path = 'dataset/spotify.csv'

# %%
df = pd.read_csv(file_path, index_col='Date', parse_dates=True)
df
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
plt.figure(figsize=(14, 6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=df)
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %%
plt.figure(figsize=(14, 6))

plt.title("Daily Global Streams of 'Shape of You' and 'Despacito' Songs in 2017-2018")

sns.lineplot(data=df['Shape of You'], label="Shape of You")
sns.lineplot(data=df['Despacito'], label="Despacito")
# Out:
# <Axes: title={'center': "Daily Global Streams of 'Shape of You' and 'Despacito' Songs in 2017-2018"}, xlabel='Date', ylabel='Shape of You'>

# %%
museum_filepath = "dataset/museum_visitors.csv"

# %%
museum_df = pd.read_csv(museum_filepath, index_col="Date", parse_dates=True)
museum_df.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
plt.figure(figsize=(14, 6))

plt.title("Museum Visitors per Month")

sns.lineplot(data=museum_df)
# Out:
# <Axes: title={'center': 'Museum Visitors per Month'}, xlabel='Date'>

# %%
plt.figure(figsize=(14, 6))
plt.title("Number of Visitors to Avila Adobe Museum Over Time")

sns.lineplot(data=museum_df['Avila Adobe'])
# Out:
# <Axes: title={'center': 'Number of Visitors to Avila Adobe Museum Over Time'}, xlabel='Date', ylabel='Avila Adobe'>

# %% [markdown]
# # Bar Charts and Heatmaps

# %%
flight_path = "dataset/flight_delays.csv"

# %%
flight_data = pd.read_csv(flight_path, index_col="Month")

# %%
flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize=(14, 6))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

sns.barplot(x=flight_data.index, y=flight_data["NK"])

plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# ## Heatmaps

# %%
# Set the width and height of the figure
plt.figure(figsize=(14, 7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=flight_data, annot=True)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %%
ign_filepath = "dataset/ign_scores.csv"

ign_data = pd.read_csv(ign_filepath, index_col="Platform")

# %%
ign_data.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %%
plt.figure(figsize=(25, 6))
plt.title("Average score for Racing Games, for each platform")

sns.barplot(x=ign_data.index, y=ign_data["Racing"])

plt.ylabel("Average Score")
# Out:
# Text(0, 0.5, 'Average Score')

# %%
# Set the width and height of the figure
plt.figure(figsize=(14, 6))

# Add title
plt.title("Average score for each Game, for each platform")

# Heatmap showing average score for each game for each platform
sns.heatmap(data=ign_data, annot=True)

# Add label for horizontal axis
plt.xlabel("Game Category")
# Out:
# Text(0.5, 36.72222222222221, 'Game Category')

# %% [markdown]
# # Scatter Plots

# %%
insurance_filepath = "dataset/insurance.csv"

insurance_data = pd.read_csv(insurance_filepath)

insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=insurance_data["bmi"], y=insurance_data["charges"])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=insurance_data["bmi"], y=insurance_data["charges"])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(
    x=insurance_data["bmi"], y=insurance_data["charges"], hue=insurance_data["smoker"]
)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# Swarmplot is used to plot when we have categorical column/feature (like "smoker" here) and the other is a numerical column/feature.
#
# The following plot shows that:
#
# - on average, non-smokers are charged less than smokers, and
# - the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.

# %%
sns.swarmplot(x=insurance_data["smoker"], y=insurance_data["charges"])
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
candy_filepath = "dataset/candy.csv"

candy_data = pd.read_csv(candy_filepath, index_col="id")

candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %% [markdown]
# Do people tend to prefer candies with higher sugar content?

# %%
sns.scatterplot(x=candy_data["sugarpercent"], y=candy_data["winpercent"])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
# Same scatter plot but with regression plot

sns.regplot(x=candy_data["sugarpercent"], y=candy_data["winpercent"])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# Since the regression line has a slightly positive slope, this tells us that there is a slightly positive correlation between 'winpercent' and 'sugarpercent'. Thus, people have a slight preference for candies containing relatively more sugar.

# %%
sns.scatterplot(x=candy_data["pricepercent"], y=candy_data["winpercent"], hue=candy_data["chocolate"])
# Out:
# <Axes: xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate", data=candy_data)

# %% [markdown]
# We'll begin with the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies). Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper. One important note, however, is that the dataset is quite small -- so we shouldn't invest too much trust in these patterns! To inspire more confidence in the results, we should add more candies to the dataset.

# %% [markdown]
# Categorical Scatter Plot

# %%
sns.swarmplot(x=candy_data["chocolate"], y=candy_data["winpercent"])
# Out:
# <Axes: xlabel='chocolate', ylabel='winpercent'>

# %% [markdown]
# # Distributions
#
# Creating histograms and density plots

# %%
iris_filepath = "dataset/iris.csv"

iris_data = pd.read_csv(iris_filepath, index_col="Id")

iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# ## Histogram

# %%
sns.histplot(iris_data["Petal Length (cm)"])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# ## Density Plots
#
# kernel density estimate (KDE) plots - smoothed histogram

# %%
# KDE plot
sns.kdeplot(data=iris_data["Petal Length (cm)"], fill=True)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
# 2D KDE plot
sns.jointplot(
    x=iris_data["Petal Length (cm)"], y=iris_data["Sepal Width (cm)"], kind="kde"
)

# %% [markdown]
# - the curve at the top of the figure is a KDE plot for the data on the x-axis (in this case, `iris_data['Petal Length (cm)']`), and
# - the curve on the right of the figure is a KDE plot for the data on the y-axis (in this case, `iris_data['Sepal Width (cm)']`).

# %%
# Histograms for each species
sns.histplot(data=iris_data, x="Petal Length (cm)", hue="Species")

# Add title
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %%
# KDE plots for each species
sns.kdeplot(data=iris_data, x="Petal Length (cm)", hue="Species", fill=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %%
cancer_filepath = "dataset/cancer.csv"

cancer_data = pd.read_csv(cancer_filepath, index_col="Id")

cancer_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
sns.histplot(data=cancer_data, x="Area (mean)", hue="Diagnosis")
# Out:
# <Axes: xlabel='Area (mean)', ylabel='Count'>

# %%
# KDE plots for each cancer
sns.kdeplot(data=cancer_data, x="Radius (worst)", hue="Diagnosis", fill=True)
# Out:
# <Axes: xlabel='Radius (worst)', ylabel='Density'>

# %% [markdown]
# # When to use what chart/plot?
#
# **Trends** - A trend is defined as a pattern of change.
# - `sns.lineplot` - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# **Relationship** - There are many different chart types that you can use to understand relationships between variables in your data.
# - `sns.barplot` - Bar charts are useful for comparing quantities corresponding to different groups.
# - `sns.heatmap` - Heatmaps can be used to find color-coded patterns in tables of numbers.
# - `sns.scatterplot` - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
# - `sns.regplot` - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
# - `sns.lmplot` - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
# - `sns.swarmplot` - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
#
# **Distribution** - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
# - `sns.histplot` - Histograms show the distribution of a single numerical variable.
# - `sns.kdeplot` - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
# - `sns.jointplot` - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# # Comic Dataset

# %%
comic_filepath = "dataset/comic_dataset/dc-wikia-data.csv"

comic_data = pd.read_csv(comic_filepath, index_col="page_id")

comic_data.head()
# Out:
#                                 name                              urlslug  \
# page_id
# 1422            Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 23387          Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 1458      Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 1659        James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 1576     Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                       ID            ALIGN         EYE        HAIR  \
# page_id
# 1422     Secret Identity  Good Characters   Blue Eyes  Black Hair
# 23387    Secret Identity  Good Characters   Blue Eyes  Black Hair
# 1458     Secret Identity  Good Characters  Brown Eyes  Brown Hair
# 1659     Public Identity  Good Characters  Brown Eyes  White Hair
# 1576     Secret Identity  Good Characters   Blue Eyes  Black Hair
#
#                      SEX  GSM              ALIVE  APPEARANCES  \
# page_id
# ...

# %%
sns.kdeplot(data=comic_data, x="YEAR", hue="SEX", fill=True)
# Out:
# <Axes: xlabel='YEAR', ylabel='Density'>

# %%
sns.lineplot(data=comic_data, x="APPEARANCES", y="SEX")
# Out:
# <Axes: xlabel='APPEARANCES', ylabel='SEX'>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=comic_data, x="SEX", hue="ALIGN")
# Out:
# <Axes: xlabel='SEX', ylabel='Count'>
